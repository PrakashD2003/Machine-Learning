# %%
import pandas as pd
import matplotlib.pyplot as plt
from autoviz.AutoViz_Class import AutoViz_Class

# %%
df = pd.read_csv(r'D:\Programming\Study\Machine Learning\Datasets\Algerian_forest_fires_dataset_UPDATE.csv')
df.head()
# Out:
#                                                                   Bejaia Region Dataset
# day month year Temperature  RH  Ws Rain  FFMC DMC DC  ISI BUI FWI         Classes
# 01  06    2012 29          57  18  0     65.7 3.4 7.6 1.3 3.4 0.5       not fire
# 02  06    2012 29          61  13  1.3   64.4 4.1 7.6 1   3.9 0.4       not fire
# 03  06    2012 26          82  22  13.1  47.1 2.5 7.1 0.3 2.7 0.1       not fire
# 04  06    2012 25          89  13  2.5   28.6 1.3 6.9 0   1.7 0         not fire

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
AV = AutoViz_Class()
dft = AV.AutoViz(df)
# Out:
# Shape of your Data Set loaded: (247, 1)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  0
#     Number of Integer-Categorical Columns =  0
#     Number of String-Categorical Columns =  1
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  0
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  0
#     Number of Date Time Columns =  0
#     Number of ID Columns =  0
#     Number of Columns to Delete =  0
#     1 Predictors classified...
#         No variables removed since no ID or low-information variables found in data set
# To fix these data quality issues in the dataset, import FixDQ from autoviz...
# There are 237 duplicate rows in your dataset
#     Alert: Dropping duplicate rows can sometimes cause your column data types to change to object!
#     All variables classified into correct types.
# <style type="text/css">
# #T_1dd55_row0_col0, #T_1dd55_row0_col3, #T_1dd55_row0_col4, #T_1dd55_row0_col5 {
#   font-family: Segoe UI;
# }
# #T_1dd55_row0_col1, #T_1dd55_row0_col2 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_1dd55">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1dd55_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_1dd55_level0_col1" class="col_heading level0 col1" >Missing Values%</th>
#       <th id="T_1dd55_level0_col2" class="col_heading level0 col2" >Unique Values%</th>
#       <th id="T_1dd55_level0_col3" class="col_heading level0 col3" >Minimum Value</th>
#       <th id="T_1dd55_level0_col4" class="col_heading level0 col4" >Maximum Value</th>
#       <th id="T_1dd55_level0_col5" class="col_heading level0 col5" >DQ Issue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1dd55_level0_row0" class="row_heading level0 row0" >Bejaia Region Dataset </th>
#       <td id="T_1dd55_row0_col0" class="data row0 col0" >object</td>
#       <td id="T_1dd55_row0_col1" class="data row0 col1" >10.000000</td>
#       <td id="T_1dd55_row0_col2" class="data row0 col2" >90</td>
#       <td id="T_1dd55_row0_col3" class="data row0 col3" ></td>
#       <td id="T_1dd55_row0_col4" class="data row0 col4" ></td>
#       <td id="T_1dd55_row0_col5" class="data row0 col5" >1 missing values. Impute them with mean, median, mode, or a constant value such as 123., Mixed dtypes: has 2 different data types:  object, float,</td>
#     </tr>
#   </tbody>
# </table>
# Could not draw Distribution Plots cannot handle a non-unique multi-index!
# All Plots done
# Time to run AutoViz = 1 seconds
#
#  ###################### AUTO VISUALIZATION Completed ########################
